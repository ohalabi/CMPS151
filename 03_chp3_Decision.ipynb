# %% [markdown]
# # Chapter (3): Decision Structures and Boolean Logic

# %% [markdown]
# ## Python Comparison Operators (Relational Operators)

# %% [markdown]
# | Operator | Name | Example |
# |---|---|---|
# | `==` | Equal | `x == y` |
# | `!=` | Not equal | `x != y` |
# | `>` | Greater than | `x > y` |
# | `<` | Less than | `x < y` |
# | `>=` | Greater than or equal to | `x >= y` |
# | `<=` | Less than or equal to | `x <= y` |

# %% [markdown]
# ## Relational Expressions

# %%
x = 5
print(x)

# %%
12 < 5 # this what is called expression

# %%
5 <= 5

# %%
x = 10
y = 7
# x == y # equality operator
# x != y
# x == 9		
x < (y + 5)

# %% [markdown]
# ## if Statement

# %%
# write a program that checks if b is greater than a or not. If it is greater than a, print "b is greater than a" otherwise print "b is smaller than a"

a = 600
b = 800
if b < a:   
  print("b is smaller than a")
  print("this is inside if statement")
  print("this is also inside if statement")
if b > a:
  print('b is greater than a')

print("this is outside if statement")

# %% [markdown]
# ## Indentation

# %%
a = 33
b = 200
if b > a:
    print("b is greater than a") # you will get an error

# %% [markdown]
# ## if/else Statement

# %%
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))
if b > a:
  print(f"{b} is greater than {a}")
  print("this is inside if statement")
else: 
  print(f"{b} is not greater than {a}")
  print("this is inside else statement")

# %%
# demonstrate the use of if and else statement in one line of code
a = 300
b = 500
print("a greater than b") if a > b else print("b greater than a")

# %% [markdown]
# ### Ask user to input number and tell if positive or negative

# %%
number = int(input('Entera number '))

if number > 0:
    print('positive')
else: # if number <= 0:
    print('negative')

# %% [markdown]
# ## Write a program to read two integer numbers and display the maximum one.

# %%
n1 = int(input('Enter first number '))
n2 = int(input('Enter second number ')) 
if n1 > n2:
    print(f"{n1} is the maximum number") 
else:
    print(f"{n2} is the maximum number")

# %%
n1 = int(input('Enter first number '))
n2 = int(input('Enter second number '))
if n1 > n2:
    print(f'first number ({n1}) is greater than second number ({n2})')
else:
    print(f'second number ({n2}) is greater than first number ({n1})')

# %%
# Read two integers from user input
number1 = int(input("Enter the first integer: "))
number2 = int(input("Enter the second integer: "))

# Compare the numbers and display the maximum one
if number1 > number2:
    print("The maximum number is:", number1)
else:
    print("The maximum number is:", number2)

# %% [markdown]
# ## Write a program to read a number and display if it is odd or even

# %%
number = int(input('Enter a number '))
if number % 2 != 0:
    print('odd')
else:
    print('even')

# %%
number = int(input("Enter an integer: "))
if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")

# %%
# Read an integer from the user
number = int(input("Enter a number: "))

# Check if the number is even or odd and display the result
if number % 2 == 0:
    print(f"The number {number} is EVEN.")
else:
    print(f"The number {number} is ODD.")

# %% [markdown]
# ### Write a program to read a salary of employee and deduct 10% tax if the salary is less than 10,000, and 15% if the salary is 10,000 or more. Your program should display the net salary.

# %%
salary = float(input("Enter your salary: "))
if salary >= 10000:
    tax_rate = 0.15 
else:
    tax_rate = 0.10
tax = salary * tax_rate
net_salary = salary - tax
# print(net_salary)
print(f" Net Salary: {net_salary:,.4f}")

# %%
salary = float(input("Enter your salary: "))
if salary < 10000:  
    tax_rate = 0.1
else:
    tax_rate = 0.15
tax = salary * tax_rate
net_salary = salary - tax
print(f"Your net salary after tax is: {net_salary}")

# %%
# Read the salary from the user
salary = float(input("Enter the employee's salary: "))

# Calculate net salary based on given conditions
if salary < 10000:
    tax = 0.10 * salary # 10%
else:
    tax = 0.15 * salary  # 15%

net_salary = salary - tax

# Display the net salary
print("The net salary after tax deduction is:", net_salary)

# %% [markdown]
# ## Nested If

# %% [markdown]
# ### If/else works when we have only two choices, but there are many cases when we have more than two choices. For example, we want to read a number from user and decide if it is zero, positive, or negative.

# %%
number = float(input("Enter a number: "))

if number == 0:
    print(f"The number {number} is zero.")
else:
    if number > 0:
        print(f"The number {number} is positive")
    else:
        print(f"The number {number} is negative")
# Out:
# The number -99.0 is negative

# %% [markdown]
# ### Write a program to read a score, and print the corresponding letter grade according to the following

# %%
score = int(input('Enter your test score: '))

# Determine the grade.
if score >= 90:
    print('Your grade is A.')
else:
    if score >= 80:
        print('Your grade is B.')
    else:
        if score >=70:
            print('Your grade is C.')
        else:
            if score >= 60:
                print('Your grade is D.')
            else:
                print('Your grade is F.')
# Out:
# Your grade is F.

# %% [markdown]
# ## The if/elif Statement

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")

# %%
score = int(input('Enter your test score: '))
if score >= 90:
	print('Your grade is A.')
elif score >= 80:
	print('Your grade is B.')
elif score >= 70:
	print('Your grade is C.')
elif score >= 60:
	print('Your grade is D.')
else: #catch all other cases
	print('Your grade is F.')

# %% [markdown]
# ## Logical Operators
#
# - **`and`**: Returns `True` if both statements are true.
#     Example: `x < 5 and x < 10`
#
# - **`or`**: Returns `True` if at least one statement is true.
#     Example: `x < 5 or x < 4`
#
# - **`not`**: Reverses the result.
#     Example: `not (x < 5 and x < 10)`

# %%
x = 12
y = 5
z = -4

# %%
(x > y) and (y > z)
# Out:
# True

# %%
(x > y) and (z > y)
# Out:
# False

# %%
(x <= z) or (y == z)
# Out:
# False

# %%
(x <= z) or (y != z)
# Out:
# True

# %%
not(x >= z)
# Out:
# False

# %% [markdown]
# | Precedence | Operator | Description |
# |---:|---|---|
# | 1 | `not` | Logical NOT |
# | 2 | `and` | Logical AND |
# | 3 | `or` | Logical OR |

# %%
(2 < 3) or (5 > 6) and (7 > 8)
# Out:
# True

# %% [markdown]
# ## Checking Numeric Ranges

# %%
# Used to test if a value is within a range like student grade
grade = int(input("enter grade: "))
if grade >= 0 and grade <= 100:
    print("Valid grade")
    
if grade < 0 or grade > 100:
    print("Invalid grade")

# %%
# Can also test if a value lies outside a range
if grade < 0 or grade > 100:
    print("Invalid grade")

# %% [markdown]
# ### Chained comparision
#     if 0<=grade<=100:  # works in Python
#      # it is equivalent to:
#
#      if 0<=grade and grade<=100:

# %%
grade = 22
if 0<= grade<= 100:
    print (grade)

# %% [markdown]
# ## Validating User Input
# - Input validation: inspecting input data to determine if it is acceptable
# - Want to avoid accepting bad input
# - Can perform various tests. Examples:
#     - Range
#     - Valid menu choice
#     - Zero as a divisor

# %%
# this program takes two integers as input and performs division, handling the case of division by zero.
input_value1 = int(input("Enter an integer: "))
input_value2 = int(input("Enter an integer: "))

if input_value2 == 0:  
    print("Error: Division by zero is not allowed.")
else:       
    result = input_value1 / input_value2
    
print(f'The result of division is: {result} ')
# Out:
# Error: Division by zero is not allowed.
# The result of division is: 2.0

# %% [markdown]
# ### Write a program to read three integer numbers and print the maximum

# %%
n1 = int(input("Enter number 1:"))
n2 = int(input("Enter number 2:"))
n3 = int(input("Enter number 3:"))
if n1>=n2 and n1>=n3:
    max = n1
elif n2>=n1 and n2>=n3:
    max = n2
else:
    max = n3
# display the max 
print(f"the max is : {max}")
# Out:
# the max is : 33

# %% [markdown]
# ### A software company sells a package that retails for QAR 99.
#
# Quantity discounts are given according to the following table:
#
# | Quantity | Discount |
# |---:|---:|
# | 1–9 | No discount |
# | 10–19 | 10% |
# | 20–49 | 20% |
# | 50–99 | 30% |
# | 100 or more | 40% |
#
# Write a program that asks the user to enter the number of packages purchased. The program should then display the amount of the discount (if any) and the total amount of the purchase after the discount.

# %%
#ask the use for number of packages
package_price = 99.0
num_packages = int(input("Enter the number of packages: "))
if num_packages < 10:
    discount = 0.0
elif 10 <= num_packages < 20:
    discount = 0.10
elif 20 <= num_packages < 50:
    discount = 0.20
elif 50<= num_packages < 100:
    discount = 0.30
elif 100 <= num_packages:
    discount = 0.40 

total_cost = num_packages * package_price * (1 - discount)  
print

# %%
package_price = 99.0
num_packages = int(input("Enter the number of packages: "))
if num_packages < 10:
    discount = 0.0
elif 10<=num_packages < 20:
    discount = 0.1
elif 20<=num_packages < 50:
    discount = 0.2  
elif 50<=num_packages < 100:    
    discount = 0.3
else:
    discount = 0.4
#calculate the totol amount of discount 
total_cost = num_packages * package_price * (1 - discount)
print(f"Total cost after discount: ${total_cost:.2f}")

# %%
package_price = 99

number_of_packages = int(input("Enter the number of packages:"))

if number_of_packages < 10:
    discount = 0
elif 10 <= number_of_packages <20:
    discount = 0.1
elif 20 <=number_of_packages <50: 
    discount = 0.2
elif 50 <=number_of_packages <100: 
    discount = 0.3
else:
    discount = 0.4

#calculate the total amout before dicount
total_before_discount = number_of_packages * package_price

# calculate the discount
discount_amount = total_before_discount * discount

#calcuate total amout after discount
total_after_discount = total_before_discount - discount_amount

print(f"Discount Amount: {discount_amount}")
print(f"Total after discount: {total_after_discount}")
# Out:
# Discount Amount: 99.0
# Total after discount: 891.0
